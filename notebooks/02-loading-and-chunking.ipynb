# %%
import sys
from pathlib import Path

sys.path.insert(0,str(Path.cwd().parent))

from src.loading import load_vault
from src.chunking import _split_string_by_headers
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 7
#       3
#       4 sys.path.insert(0,str(Path.cwd().parent))
#       5
#       6 from src.loading import load_vault
# ----> 7 from src.chunking import _split_string_by_headers
#       8
#
# ImportError: cannot import name '_split_string_by_headers' from 'src.chunking' (c:\Users\eoinm\Documents\rag-build-project\src\chunking.py)
