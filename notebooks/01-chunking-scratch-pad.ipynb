# %% [markdown]
# # 1. Chunking Build - Scratch Pad
#
# Testing best logic to break up markdown files by headings and levels
#
# ### Imports
# - Regex: used for identify markdown headings such as # Heading 1, ## Heading 2
# - Frontmatter: for loading in YAML frontmatter from .md files
# - Path: for working with directories

# %%
import re
import frontmatter
from pathlib import Path

# %% [markdown]
# ### Build Regex & load in Example .md

# %%
HEADING_RE = re.compile(r"^(#{1,4})\s+(.*)$")

EXAMPLE_PATH = Path('example.md')

with EXAMPLE_PATH.open(encoding = 'UTF-8') as file:
    example_file = frontmatter.load(file)

example_text = example_file.content

display(example_text)
# Out:
# '# Heading 1\nexample text here\n\n## Heading 2\nMore text here\nText again\n\n### Heading 3\nmore example text\n\n## Heading 2 \nFinal example text'

# %% [markdown]
# ### Testing out function to identify Headers and compile the text into sections

# %%
def _split_string_by_headers(content:str) -> list[tuple[list[str],str]]:

    sections: list[tuple[list[str],str]] = []
    heading_stack: list[str] = []
    compiled_text: list[str] = []

    for line in content.splitlines():

        heading_match = HEADING_RE.match(line)
        if heading_match:
            heading_text = heading_match.group(2).strip()
            text = "\n".join(compiled_text).strip()
            
            if text:
                sections.append((list(heading_stack),text))
                compiled_text.clear()
            
            heading_level = len(heading_match.group(1))
            del heading_stack[heading_level - 1:]
            heading_stack.append(heading_text)
            

        else:
            compiled_text.append(line)
        
    text = "\n".join(compiled_text).strip()
    if text or heading_stack:
        sections.append((heading_stack,text))

    return sections


_split_string_by_headers(example_text)
# Out:
# [(['Heading 1'], 'example text here'),
#  (['Heading 1', 'Heading 2'], 'More text here\nText again'),
#  (['Heading 1', 'Heading 2', 'Heading 3'], 'more example text'),
#  (['Heading 1', 'Heading 2'], 'Final example text')]
